# %% [markdown]
# <a href="https://colab.research.google.com/github/imammarzuki/pythonpemula/blob/main/26_While.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tutorial Belajar Python Part 26: Perulangan While Bahasa Python

# %%
i = 1
while i <= 5:
  print('Duniailkom')
  i += 1
# Out:
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom

# %%
i = 1
while i <= 5:
  print('Duniailkom')
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# ...

# %%
i = 1
while i <= 5:
  print('Duniailkom')    #infinity loop
i += 1
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# Duniailkom
# ...

# %%
i = 1
while i <= 5:
  print('Duniailkom', i)
  i += 1
# Out:
# Duniailkom 1
# Duniailkom 2
# Duniailkom 3
# Duniailkom 4
# Duniailkom 5

# %%
i = 10
while i > 5:
  print('Duniailkom', i)
  i -= 1
# Out:
# Duniailkom 10
# Duniailkom 9
# Duniailkom 8
# Duniailkom 7
# Duniailkom 6

# %%
i = 3
while i < 100:
  print(i)
  i = i + 3
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %%
i = 10
while i <= 5:
  print('Duniailkom', i)
  i -= 1
